# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Sigmoid Function

# %% [markdown]
# The sigmoid function converts the estimated value into probability (between 0 and 1)

# %%
from IPython.display import Image

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.figure(figsize=(15,12))
img=mpimg.imread('images\sigmoid function.jpg')
implot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b5fd60a936f9> in <module>
#       3 import matplotlib.image as mpimg
#       4 plt.figure(figsize=(15,12))
# ----> 5 img=mpimg.imread('images\sigmoid function.jpg')
#       6 implot = plt.imshow(img)
#       7 plt.show()
#
# C:\anaconda36\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1349                              'with Pillow installed matplotlib can handle '
#    1350                              'more images' % list(handlers))
# -> 1351         with Image.open(fname) as image:
#    1352             return pil_to_array(image)
#    1353
#
# C:\anaconda36\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2632
#    2633     if filename:
# -> 2634         fp = builtins.open(filename, "rb")
# ...

# %%
import math

def basic_sigmoid(x):

    s = 1/(1+ math.exp(-x))
    
    return s

# %%
basic_sigmoid(3)
# Out:
# 0.9525741268224334

# %%
# Actually, we rarely use the "math" library in deep learning because the inputs of the functions are real numbers. In deep learning we mostly use matrices and vectors. This is why numpy is more useful

import numpy as np

def basic_sigmoid(x):
    
    s = 1/(1+ np.exp(-x))
    
    return s

x = np.array([1,2,3])

basic_sigmoid(x)
# Out:
# array([0.73105858, 0.88079708, 0.95257413])

# %% [markdown]
# ### Loss Function & Cost Function

# %% [markdown]
# The loss function computes the error for a single training example; the cost function is the average of the cost function of the entire training set

# %%
plt.figure(figsize=(16,18))
img=mpimg.imread('loss function by Andrew Ng.png')
implot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### L1 Loss Function

# %% [markdown]
# - L1 loss is defined as:
# $$\begin{align*} & L_1(\hat{y}, y) = \sum_{i=0}^m|y^{(i)} - \hat{y}^{(i)}| \end{align*}\tag{6}$$

# %%
# GRADED FUNCTION: L1

def L1(yhat, y):
    """
    Arguments:
    yhat -- vector of size m (predicted labels)
    y -- vector of size m (true labels)
    
    Returns:
    loss -- the value of the L1 loss function defined above
    """
    
    ### START CODE HERE ### (≈ 1 line of code)
    loss = np.sum(np.abs(y - yhat))
    ### END CODE HERE ###
    
    return loss

# %%
yhat = np.array([.9, 0.2, 0.1, .4, .9])
y = np.array([1, 0, 0, 1, 1])
print("L1 = " + str(L1(yhat,y)))
# Out:
# L1 = 1.1

# %% [markdown]
# ### L2 Loss

# %% [markdown]
# - L2 loss is defined as $$\begin{align*} & L_2(\hat{y},y) = \sum_{i=0}^m(y^{(i)} - \hat{y}^{(i)})^2 \end{align*}\tag{7}$$

# %%
def L2(yhat, y):
    """
    Arguments:
    yhat -- vector of size m (predicted labels)
    y -- vector of size m (true labels)
    
    Returns:
    loss -- the value of the L2 loss function defined above
    """
    
    ### START CODE HERE ### (≈ 1 line of code)
    loss = np.sum(np.square(y-yhat))
    ### END CODE HERE ###
    
    return loss

# %% [markdown]
# ### L1 AND L2 Loss Function and Regularization
# http://www.chioka.in/differences-between-l1-and-l2-as-loss-function-and-regularization/

# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# Gradient descen is a simple optimization procedure that calculate the derivative from all the training data before calculating an update. The repetative process continues until it reaches a local optimum.
#
# The derivative of a function means the slope of a function.
# The slope of the function can be different on the different points on the curve depending on the function.

# %%
plt.figure(figsize=(16,18))
img=mpimg.imread('gradient descent.png')
implot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### Logistic Regression Gradient Descent on m Examples

# %%
plt.figure(figsize=(16,18))
img=mpimg.imread('logistic regression on m examples.png')
implot = plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(16,18))
img=mpimg.imread('vectorization of logistic regression.png')
implot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### Vectorization

# %% [markdown]
# np.dot(a,b)" performs a matrix multiplication on a and b, whereas "a*b" performs an element-wise multiplication

# %%
import time

a = np.random.rand(1000000)
b = np.random.rand(1000000)

tic = time.time()
c = np.dot(a,b)
toc = time.time()

print(c)
print("Vectorized version:" + str(1000*(toc-tic))+"ms")

# non-vectorized version
c=0
tic = time.time()
for i in range(1000000):
    c+=a[i]*b[i]
toc = time.time()

print(c)
print("For loop:" + str(1000*(toc - tic)) +"ms")

# %%
x1 = [9, 2, 5, 0, 0, 7, 5, 0, 0, 0, 9, 2, 5, 0, 0]
x2 = [9, 2, 2, 9, 0, 9, 2, 5, 0, 0, 9, 2, 5, 0, 0]

### VECTORIZED DOT PRODUCT OF VECTORS ###
tic = time.process_time()
dot = np.dot(x1,x2)
toc = time.process_time()
print ("dot = " + str(dot) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")

### VECTORIZED OUTER PRODUCT ###
tic = time.process_time()
outer = np.outer(x1,x2)
toc = time.process_time()
print ("outer = " + str(outer) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")

### VECTORIZED ELEMENTWISE MULTIPLICATION ###
tic = time.process_time()
mul = np.multiply(x1,x2)
toc = time.process_time()
print ("elementwise multiplication = " + str(mul) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")

### VECTORIZED GENERAL DOT PRODUCT ###
tic = time.process_time()
dot = np.dot(W,x1)
toc = time.process_time()
print ("gdot = " + str(dot) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")

# %% [markdown]
# ### Array Broadcasting

# %% [markdown]
# The term broadcasting refers to the ability of NumPy to treat arrays of different shapes during arithmetic operations.

# %%
import numpy as np

A = np.array([[56.0,0.0,4.4,68.0],
             [1.2, 104.0, 52.0, 8.0],
             [1.8, 135.0, 99.0, 0.9]])

print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    8. ]
#  [  1.8 135.   99.    0.9]]

# %%
cal = A.sum(axis=0) # axis=0 sums vertically, axis=1 sums horizontally
print(cal)
print(type(cal))
print(cal.reshape(1,4))

percentage = 100*A/cal.reshape(1,4)
print(percentage)
# Out:
# [ 59.  239.  155.4  76.9]
# <class 'numpy.ndarray'>
# [[ 59.  239.  155.4  76.9]]
# [[94.91525424  0.          2.83140283 88.42652796]
#  [ 2.03389831 43.51464435 33.46203346 10.40312094]
#  [ 3.05084746 56.48535565 63.70656371  1.17035111]]

# %%
import numpy as np

# this creates rank 1 array (do not use)
a = np.random.randn(5)
print(a)
print(a.shape)

a = np.random.randn(5,1) # creates column vector
print(a)
print(a.T)
print(np.dot(a,a.T))
# Out:
# [-0.09593731  1.29218376  0.52140887  0.33729593  0.23106006]
# (5,)
# [[ 0.67192745]
#  [ 0.8805953 ]
#  [-0.15206793]
#  [-0.42838222]
#  [ 0.97527862]]
# [[ 0.67192745  0.8805953  -0.15206793 -0.42838222  0.97527862]]
# [[ 0.4514865   0.59169615 -0.10217862 -0.28784177  0.65531648]
#  [ 0.59169615  0.77544808 -0.13391031 -0.37723137  0.85882577]
#  [-0.10217862 -0.13391031  0.02312466  0.0651432  -0.1483086 ]
#  [-0.28784177 -0.37723137  0.0651432   0.18351132 -0.41779202]
#  [ 0.65531648  0.85882577 -0.1483086  -0.41779202  0.95116839]]

# %%
assert(a.shape == (5,1))

# %%
What does a neuron compute: a linear function z=Wx+b followed by an activation function

# %%
a = np.random.randn(2,3)
print(a)

b= np.random.randn(2,1)
print(b)

c= a+b
print(c.shape)
print(c)
# Out:
# [[-0.85741753 -1.14756022 -0.7916298 ]
#  [-0.92392404  0.1286672  -0.49337828]]
# [[1.19056019]
#  [2.27268474]]
# (2, 3)
# [[0.33314267 0.04299997 0.39893039]
#  [1.3487607  2.40135194 1.77930646]]

# %%
a = np.random.randn(12288, 150) # a.shape = (12288, 150)
b = np.random.randn(150, 45) # b.shape = (150, 45)
c = np.dot(a,b)
print(c.shape)
# Out:
# (12288, 45)

# %%
a = np.random.randn(4, 3) # a.shape = (4, 3)
b = np.random.randn(3, 2) # b.shape = (3, 2)
c = a*b
print(c.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-e51bf1949f07> in <module>()
#       1 a = np.random.randn(4, 3) # a.shape = (4, 3)
#       2 b = np.random.randn(3, 2) # b.shape = (3, 2)
# ----> 3 c = a*b
#       4 print(c.shape)
#
# ValueError: operands could not be broadcast together with shapes (4,3) (3,2)

# %%
a = np.random.randn(3, 3)
b = np.random.randn(3, 1)
c = a*b
print(a)
print(b)
print(c)
# Out:
# [[-0.34856172 -0.18078468 -0.31811934]
#  [ 0.04744996  0.68415663 -2.43670446]
#  [ 0.32453769 -1.49746971 -0.14761756]]
# [[ 0.12404523]
#  [-0.07483622]
#  [ 1.00385171]]
# [[-0.04323742 -0.02242548 -0.03946119]
#  [-0.00355098 -0.0511997   0.18235376]
#  [ 0.32578772 -1.50323753 -0.14818614]]

# %% [markdown]
# ### TP/FP/TN/FN

# %% [markdown]
# - True Positive: Correctly Classified Fraud Transactions
# - False Positives: Incorrectly Classified Fraud Transactions
# - True Negative: Correctly Classified Non-Fraud Transactions
# - False Negative: Incorrectly Classified Non-Fraud Transactions
#
# - Precision: True Positives/(True Positives + False Positives)
# - Recall: True Positives/(True Positives + False Negatives)
# - Precision as the name says, says how precise (how sure) is our model in detecting fraud transactions while recall is the amount of fraud cases our model is able to detect.
#
# - Precision/Recall Tradeoff: The more precise (selective) our model is, the less cases it will detect. Example: Assuming that our model has a precision of 95%, Let's say there are only 5 fraud cases in which the model is 95% precise or more that these are fraud cases. Then let's say there are 5 more cases that our model considers 90% to be a fraud case, if we lower the precision there are more cases that our model will be able to detect.
#
# Precision starts to descend between 0.90 and 0.92 nevertheless, our precision score is still pretty high and still we have a descent recall score.

# %% [markdown]
# ### Two Important Parameters

# %% [markdown]
# #### solver : str, {‘newton-cg’, ‘lbfgs’, ‘liblinear’, ‘sag’, ‘saga’}, default: ‘liblinear’.
# Algorithm to use in the optimization problem.
#
# For small datasets, ‘liblinear’ is a good choice, whereas ‘sag’ and ‘saga’ are faster for large ones.
# For multiclass problems, only ‘newton-cg’, ‘sag’, ‘saga’ and ‘lbfgs’ handle multinomial loss; ‘liblinear’ is limited to one-versus-rest schemes.
# ‘newton-cg’, ‘lbfgs’ and ‘sag’ only handle L2 penalty, whereas ‘liblinear’ and ‘saga’ handle L1 penalty.

# %% [markdown]
# #### multi_class : str, {‘ovr’, ‘multinomial’, ‘auto’}, default: ‘ovr’
#
# If the option chosen is ‘ovr’, then a binary problem is fit for each label. For ‘multinomial’ the loss minimised is the multinomial loss fit across the entire probability distribution, even when the data is binary. ‘multinomial’ is unavailable when solver=’liblinear’. ‘auto’ selects ‘ovr’ if the data is binary, or if solver=’liblinear’, and otherwise selects ‘multinomial’.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_row', None)
pd.set_option('display.max_column', None)

train = pd.read_pickle('titanic_train.pkl')
test = pd.read_pickle('titanic_test.pkl')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import r2_score, mean_squared_error, roc_auc_score, confusion_matrix, classification_report

# %%
numeric_features = [i for i in train.columns if train[i].dtype!=np.dtype('object') and i not in ['PassengerId', 'Survived', 'rf_score']]

# %%
X=train[numeric_features]
y=train['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr=LogisticRegression(random_state=0)

lr.fit(X_train,y_train)

from sklearn import model_selection
print("accuracy: ", model_selection.cross_val_score(lr,X_train,y_train,scoring='accuracy').mean())
print("precision: ", model_selection.cross_val_score(lr,X_train,y_train,scoring='precision').mean())
print("recall: ", model_selection.cross_val_score(lr,X_train,y_train,scoring='recall').mean())
print("rocauc: ", roc_auc_score(y_test.values,lr.predict_proba(X_test)[:,1]))
# Out:
# accuracy:  0.8234469837730707
# precision:  0.7839425441538118
# recall:  0.722943722943723
# rocauc:  0.8908016296551329

# %%
y_pred=lr.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[138  19]
#  [ 26  85]]
#              precision    recall  f1-score   support
#
#           0       0.84      0.88      0.86       157
#           1       0.82      0.77      0.79       111
#
# avg / total       0.83      0.83      0.83       268

# %%
# cross_val_score is good for cv; if you are not doing cv, then you can call other scoring functions directly

# %%
# Define error measure for official scoring : RMSE
# bug in scikit learn, need to apply - to reverse the score
def rmse_cv_train(model):
    rmse = np.sqrt(-cross_val_score(model,X_train,y_train.values.ravel(),scoring ="neg_mean_squared_error",cv=5))
    return (rmse)
def rmse_cv_test(model):
    rmse = np.sqrt(-cross_val_score(model,X_test,y_test.values.ravel(),scoring ="neg_mean_squared_error",cv=5))
    return (rmse)

# %% [markdown]
# ### Advanced Regression Techniques
#
# ### Ridge Regression with regularization (L2 Regulization)
#
# Ridge Regression is a technique for analyze multiple regression data that suffers from multi-collinearity.
# As we increase the value of alpha, the magnitude of the coefficients decreases, where the values reaches to zero but not absolute zero
# it will retain all of the features but will shrink the coefficients

# %% [markdown]
# ### RidgeClassifierCV

# %%
# from sklearn.linear_model import RidgeCV
from sklearn.linear_model import RidgeClassifierCV                               
ridge=RidgeClassifierCV(alphas=[0.01, 0.02,0.05,0.08,1,2,5,3,10,20,30], cv=None)
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("Best alpha:", alpha)

print("Try again for more precision with alphas centered around " + str(alpha))

ridge = RidgeClassifierCV(alphas=[alpha * .5, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                        alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                        alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], cv=None)

ridge.fit(X_train, y_train)
alpha=ridge.alpha_
print("Best alpha:", alpha)

ridge2=RidgeClassifier(alpha=ridge.alpha_)
ridge2.fit(X_train, y_train)

y_train_rdg = ridge2.predict(X_train)
y_test_rdg = ridge2.predict(X_test)

print("ROC AUC Score: ", roc_auc_score(y_test, y_test_rdg))
print("Accuracy score", model_selection.cross_val_score(ridge2, X_test, y_test, scoring='accuracy').mean())
# Out:
# Best alpha: 10.0
# Try again for more precision with alphas centered around 10.0
# Best alpha: 10.0
# ROC AUC Score:  0.817868824238251
# Accuracy score 0.8022055763628796

# %% [markdown]
# ### RidgeCV

# %%
# 2 Sklearn has built-in function for Ridge regression, Lasso regression etc.
from sklearn.linear_model import RidgeCV
ridge = RidgeCV(alphas = [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60])
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("Best alpha :", alpha)

print("Try again for more precision with alphas centered around " + str(alpha))
ridge = RidgeCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                          alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                          alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], 
                cv = 10)
ridge.fit(x_train, y_train)
alpha = ridge.alpha_
print("Best alpha :", alpha)

print("Ridge RMSE on Training set :", rmse_cv_train(ridge).mean())
print("Ridge RMSE on Test set :", rmse_cv_test(ridge).mean())
y_train_rdg = ridge.predict(x_train)
y_test_rdg = ridge.predict(x_test)

# Plot predictions
plt.scatter(y_train_rdg, y_train, c = "blue", marker = "o", label = "Training data")
plt.scatter(y_test_rdg, y_test, c = "lightgreen", marker = "o", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.show()

# Plot important coefficients
coefs = pd.Series(ridge.coef_[0], index = x_train.columns)
print("Ridge picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")

# print top 20 important variables
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh",figsize=(9,11))
plt.title("Coefficients in the Ridge Model")
plt.show()

#get filtered column names
train.columns[np.where(ridge.coef_[0]==0)].values

# %% [markdown]
# ### Lasso Regression (L1 Regularization)

# %% [markdown]
# Even at smaller alpha’s, our coefficients are reducing to absolute zeroes. Therefore, lasso selects the only some feature while reduces the coefficients of others to zero. This property is known as feature selection and which is absent in case of ridge.
#
# It is generally used when we have more number of features, because it automatically does feature selection.

# %%
# 3* Lasso
from sklearn.linear_model import LassoCV, Lasso
lasso = LassoCV(alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 
                          0.3, 0.6, 1], 
                max_iter = 50000, cv = 10)
# lasso.fit(X_train, y_train.values.ravel())
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("Best alpha :", alpha)

print("Try again for more precision with alphas centered around " + str(alpha))
lasso = LassoCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, 
                          alpha * .85, alpha * .9, alpha * .95, alpha, alpha * 1.05, 
                          alpha * 1.1, alpha * 1.15, alpha * 1.25, alpha * 1.3, alpha * 1.35, 
                          alpha * 1.4], 
                max_iter = 50000, cv = 10)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("Best alpha :", alpha)

lasso2 = Lasso(alpha=lasso.alpha_)
lasso2.fit(X_train, y_train)

# y_test_las=lasso2.predict_proba(X_test)[:,1]
print("Lasso RMSE on Training set :", rmse_cv_train(lasso2).mean())
print("Lasso RMSE on Test set :", rmse_cv_test(lasso2).mean())
# y_train_las = lasso.predict(x_train)
# y_test_las = lasso.predict(x_test)

# # Plot predictions
# plt.scatter(np.expand_dims(y_train_las,axis=1), y_train, c = "blue", marker = "o", label = "Training data")
# plt.scatter(np.expand_dims(y_test_las,axis=1), y_test, c = "lightgreen", marker = "o", label = "Validation data")
# plt.title("Linear regression with Lasso regularization")
# plt.xlabel("Predicted values")
# plt.ylabel("Real values")
# plt.legend()
# plt.show()

# # Plot important coefficients
# coefs = pd.Series(lasso.coef_, index = x_train.columns)
# print("Lasso picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
#       str(sum(coefs == 0)) + " features")
# imp_coefs = pd.concat([coefs.sort_values().head(10),
#                      coefs.sort_values().tail(10)])
# imp_coefs.plot(kind = "barh",figsize=(9,11))
# plt.title("Coefficients in the Lasso Model")
# plt.show()
# Out:
# Best alpha : 0.003
# Try again for more precision with alphas centered around 0.003
# Best alpha : 0.0024000000000000002
# Lasso RMSE on Training set : 0.3741321545421835
# Lasso RMSE on Test set : 0.3721858802161369

# %% [markdown]
# ### Elastic Net

# %%
from sklearn.linear_model import ElasticNetCV
elasticNet = ElasticNetCV(l1_ratio = [0.1, 0.3, 0.5, 0.6, 0.7, 0.8, 0.85, 0.9, 0.95, 1],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 
                                    0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
elasticNet.fit(house_X_train, house_Y_train.ravel())
alpha = elasticNet.alpha_
ratio = elasticNet.l1_ratio_
print("Best l1_ratio :", ratio)
print("Best alpha :", alpha )

print("Try again for more precision with l1_ratio centered around " + str(ratio))
elasticNet = ElasticNetCV(l1_ratio = [ratio * .85, ratio * .9, ratio * .95, ratio, ratio * 1.05, ratio * 1.1, ratio * 1.15],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
elasticNet.fit(house_X_train, house_Y_train.ravel())
if (elasticNet.l1_ratio_ > 1):
    elasticNet.l1_ratio_ = 1    
alpha = elasticNet.alpha_
ratio = elasticNet.l1_ratio_
print("Best l1_ratio :", ratio)
print("Best alpha :", alpha )

print("Now try again for more precision on alpha, with l1_ratio fixed at " + str(ratio) + 
      " and alpha centered around " + str(alpha))
elasticNet = ElasticNetCV(l1_ratio = ratio,
                          alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, alpha * .9, 
                                    alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15, alpha * 1.25, alpha * 1.3, 
                                    alpha * 1.35, alpha * 1.4], 
                          max_iter = 50000, cv = 10)
elasticNet.fit(house_X_train, house_Y_train.ravel())
if (elasticNet.l1_ratio_ > 1):
    elasticNet.l1_ratio_ = 1    
alpha = elasticNet.alpha_
ratio = elasticNet.l1_ratio_
print("Best l1_ratio :", ratio)
print("Best alpha :", alpha )

print("ElasticNet RMSE on Training set :", rmse_cv_train(elasticNet).mean())
print("ElasticNet RMSE on Test set :", rmse_cv_test(elasticNet).mean())

# %% [markdown]
# ### Variable Importance

# %%
# Plot important coefficients
coefs = pd.Series(best_est.coef_[0], index = train_X.columns)
print("LogReg_somte picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh",figsize=(9,11))
plt.title("Coefficients in the LogReg_smote Model")
plt.show()
